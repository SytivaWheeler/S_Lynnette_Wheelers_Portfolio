# %% [markdown]
# # Housing, Social and Economic Characteristics Dataset

# %% [markdown]
# This code displays the economic characteristics datatset.

# %%
import pandas as pd
pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 10)

econ = pd.read_csv("../../../../data/econ_data_with_overlays.csv", low_memory=False)
econdt = pd.DataFrame(econ)
econdt
# Out:
#               GEO_ID                              NAME  \
# 0                 id              Geographic Area Name
# 1     0500000US01001           Autauga County, Alabama
# 2     0500000US01003           Baldwin County, Alabama
# 3     0500000US01005           Barbour County, Alabama
# 4     0500000US01007              Bibb County, Alabama
# ...              ...                               ...
# 3216  0500000US72145  Vega Baja Municipio, Puerto Rico
# 3217  0500000US72147    Vieques Municipio, Puerto Rico
# 3218  0500000US72149   Villalba Municipio, Puerto Rico
# 3219  0500000US72151    Yabucoa Municipio, Puerto Rico
# 3220  0500000US72153      Yauco Municipio, Puerto Rico
#
#                                              DP03_0001E  \
# 0     Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                                 43953
# 2                                                172297
# 3                                                 20636
# ...

# %% [markdown]
# This code displays the housing characteristics datatset.

# %%
import pandas as pd
pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 10)

housing = pd.read_csv("../../../../data/housing_data_with_overlays.csv", low_memory=False)
housingdt = pd.DataFrame(housing)
housingdt
# Out:
#               GEO_ID                              NAME  \
# 0                 id              Geographic Area Name
# 1     0500000US01001           Autauga County, Alabama
# 2     0500000US01003           Baldwin County, Alabama
# 3     0500000US01005           Barbour County, Alabama
# 4     0500000US01007              Bibb County, Alabama
# ...              ...                               ...
# 3216  0500000US72145  Vega Baja Municipio, Puerto Rico
# 3217  0500000US72147    Vieques Municipio, Puerto Rico
# 3218  0500000US72149   Villalba Municipio, Puerto Rico
# 3219  0500000US72151    Yabucoa Municipio, Puerto Rico
# 3220  0500000US72153      Yauco Municipio, Puerto Rico
#
#                                             DP04_0001E  \
# 0     Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                                23493
# 2                                               114164
# 3                                                12013
# ...

# %% [markdown]
# This code displays the social characteristics datatset.

# %%
import pandas as pd
pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 10)

social = pd.read_csv("../../../../data/social_data_with_overlays.csv", low_memory=False)
socialdt = pd.DataFrame(social)
socialdt
# Out:
#               GEO_ID                              NAME  \
# 0                 id              Geographic Area Name
# 1     0500000US01001           Autauga County, Alabama
# 2     0500000US01003           Baldwin County, Alabama
# 3     0500000US01005           Barbour County, Alabama
# 4     0500000US01007              Bibb County, Alabama
# ...              ...                               ...
# 3216  0500000US72145  Vega Baja Municipio, Puerto Rico
# 3217  0500000US72147    Vieques Municipio, Puerto Rico
# 3218  0500000US72149   Villalba Municipio, Puerto Rico
# 3219  0500000US72151    Yabucoa Municipio, Puerto Rico
# 3220  0500000US72153      Yauco Municipio, Puerto Rico
#
#                                           DP02_0001E  \
# 0     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1                                              21397
# 2                                              80930
# 3                                               9345
# ...
